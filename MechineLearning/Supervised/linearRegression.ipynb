# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

 
#buat data jumlah kamar
bedrooms = np.array([1,1,2,2,3,4,4,5,5,5,4,4,4,5,5,5,4])

# %%
#data harga rumah. asumsi dalam dollar
house_price = np.array([15000, 18000, 27000, 34000, 50000, 68000, 65000, 81000, 85000, 90000, 30000, 38000, 27000, 54000, 68000, 67000, 34000])

plt.scatter(bedrooms, house_price)

# %%
# latih model dengan Linear Regression.fit()
bedrooms = bedrooms.reshape(-1, 1)
linreg = LinearRegression()
linreg.fit(bedrooms, house_price)
# Out:
# LinearRegression()

# %%
# menampilkan plot hubungan antara jumlah kamar dengan harga rumah
plt.scatter(bedrooms, house_price, color="green")
plt.plot(bedrooms, linreg.predict(bedrooms))
